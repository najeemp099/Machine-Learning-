# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

df = pd.read_csv("homeprices.csv")

# %%
# Scatter Plot data 
import matplotlib.pyplot as plt

plt.xlabel("area (sq-fit)")
plt.ylabel("price (US$)")
plt.title("House Predicion System ")
plt.scatter(df.area,df.price,color = "red",marker = "*")

# %%
reg = linear_model.LinearRegression()

reg.fit(df[["area"]],df.price) #fitting means you are training the linear regression model using the available data points
# Out:
# LinearRegression()
